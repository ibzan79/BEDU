# %% [markdown]
# <a href="https://colab.research.google.com/github/ibzan79/BEDU/blob/main/proyecto_BEDU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_2020 = pd.read_csv('https://raw.githubusercontent.com/IsmaelOr/BEDU_Proyecto_Python_Equipo15/main/Files/TMod_Vic_2020.csv', sep = ',')
df_2020.insert(0, 'anio', 2020) # Se agrega una nueva columna con el año de la encuesta 
# print(df_2020.columns.to_list())

df_2019 = pd.read_csv('https://raw.githubusercontent.com/IsmaelOr/BEDU_Proyecto_Python_Equipo15/main/Files/TMod_Vic_2019.csv')
df_2019.insert(0, 'anio', 2019)

df_2018 = pd.read_csv('https://raw.githubusercontent.com/IsmaelOr/BEDU_Proyecto_Python_Equipo15/main/Files/TMod_Vic_2018.csv')
df_2018.insert(0, 'anio', 2018)

df_2017 = pd.read_csv('https://raw.githubusercontent.com/IsmaelOr/BEDU_Proyecto_Python_Equipo15/main/Files/TMod_Vic_2017.csv')
df_2017.insert(0, 'anio', 2017)

df_2016 = pd.read_csv('https://raw.githubusercontent.com/IsmaelOr/BEDU_Proyecto_Python_Equipo15/main/Files/TMod_Vic_2016.csv')
df_2016.insert(0, 'anio', 2016)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (14,125) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 5053325

# %%
print(df_2020.columns)
print(df_2019.columns)
print(df_2018.columns)
print(df_2017.columns)
print(df_2016.columns)
# Out:
# Index(['anio', 'ID_VIV', 'ID_HOG', 'ID_PER', 'ID_DEL', 'UPM', 'VIV_SEL',
#        'HOGAR', 'ND_TIPO', 'TD_TIPO',
#        ...
#        'BP6_1', 'BP6_2', 'BP6_3', 'BP7_1', 'FAC_DEL', 'FAC_DEL_AM', 'DOMINIO',
#        'ESTRATO', 'EST_DIS', 'UPM_DIS'],
#       dtype='object', length=131)
# Index(['anio', 'ID_VIV', 'ID_HOG', 'ID_PER', 'ID_DEL', 'UPM', 'VIV_SEL',
#        'HOGAR', 'ND_TIPO', 'TD_TIPO',
#        ...
#        'BP6_1', 'BP6_2', 'BP6_3', 'BP7_1', 'FAC_DEL', 'FAC_DEL_AM', 'DOMINIO',
#        'ESTRATO', 'EST_DIS', 'UPM_DIS'],
#       dtype='object', length=130)
# Index(['anio', 'ID_VIV', 'ID_HOG', 'ID_PER', 'ID_DEL', 'UPM', 'VIV_SEL',
#        'HOGAR', 'ND_TIPO', 'TD_TIPO',
#        ...
#        'BP6_1', 'BP6_2', 'BP6_3', 'BP7_1', 'FAC_DEL', 'FAC_DEL_AM', 'DOMINIO',
#        'ESTRATO', 'EST_DIS', 'UPM_DIS'],
#       dtype='object', length=130)
# Index(['anio', 'ID_VIV', 'ID_HOG', 'ID_PER', 'ID_DEL', 'UPM', 'VIV_SEL',
#        'HOGAR', 'ND_TIPO', 'TD_TIPO',
#        ...
# ...

# %%
df_delitos = pd.concat([df_2020, df_2019, df_2018, df_2017, df_2016], axis = 0)

print(df_delitos.columns.to_list())
# Out:
# ['anio', 'ID_VIV', 'ID_HOG', 'ID_PER', 'ID_DEL', 'UPM', 'VIV_SEL', 'HOGAR', 'ND_TIPO', 'TD_TIPO', 'BPCOD', 'R_SEL', 'RESUL_H', 'SEXO', 'EDAD', 'AREAM_OCU', 'BP1_1', 'BP1_2C', 'BP1_3C', 'BP1_4', 'BP1_5', 'BP1_6', 'BP1_7', 'BP1_8', 'BP1_9', 'BP1_10_1', 'BP1_10_2', 'BP1_10_9', 'BP1_11', 'BP1_12_1', 'BP1_12_2', 'BP1_12_3', 'BP1_12_4', 'BP1_12_5', 'BP1_12_9', 'BP1_13', 'BP1_14_1', 'BP1_14_2', 'BP1_14_
_36_11', 'BP1_36_99', 'BP2_1', 'BP3_1_01', 'BP3_1_02', 'BP3_1_03', 'BP3_1_04', 'BP3_1_05', 'BP3_1_06', 'BP3_1_07', 'BP3_1_08', 'BP3_1_09', 'BP3_1_10', 'BP3_1_11', 'BP3_1_12', 'BP3_1_99', 'BP3_2', 'BP4_1', 'BP5_1', 'BP5_2_1', 'BP5_2_2', 'BP5_2_3', 'BP5_2_4', 'BP5_3', 'BP6_1', 'BP6_2', 'BP6_3', 'BP7_1', 'FAC_DEL', 'FAC_DEL_AM', 'DOMINIO', 'ESTRATO', 'EST_DIS', 'UPM_DIS']

# %%
df_delitos.to_csv('df_delitos_1.csv')

# %%
df_delitos.drop(columns = ['ID_VIV', 'ID_HOG', 'ID_PER', 'ID_DEL', 'UPM', 'VIV_SEL', 'HOGAR', 'ND_TIPO', 'TD_TIPO', 'R_SEL', 'RESUL_H', 'BP1_22', 'BP1_31_01', 'BP1_31_02', 'BP1_31_03', 'BP1_31_04', 'BP1_31_05', 'BP1_31_06', 'BP1_31_07', 'BP1_31_08', 'BP1_31_09', 'BP1_31_99', 'BP1_36_01', 'BP1_36_02', 'BP1_36_03', 'BP1_36_04', 'BP1_36_05', 'BP1_36_06', 'BP1_36_07', 'BP1_36_08', 'BP1_36_09', 'BP1_36_10', 'BP1_36_11', 'BP1_36_99', 'FAC_DEL', 'FAC_DEL_AM', 'EST_DIS', 'UPM_DIS'])
# Out:
#        anio  BPCOD  SEXO  EDAD  ... BP1_25_1  BP1_25_2  BP1_26_1  BP1_26_2
# 0      2020      4   1.0  40.0  ...      NaN       NaN       NaN       NaN
# 1      2020      3   2.0  23.0  ...      NaN       NaN       NaN       NaN
# 2      2020     13   2.0  36.0  ...      NaN       NaN       NaN       NaN
# 3      2020      6   2.0  36.0  ...      NaN       NaN       NaN       NaN
# 4      2020      2   1.0  34.0  ...      NaN       NaN       NaN       NaN
# ...     ...    ...   ...   ...  ...      ...       ...       ...       ...
# 40021  2016      9   NaN   NaN  ...      NaN       NaN       NaN       NaN
# 40022  2016      9   NaN   NaN  ...      NaN       NaN       NaN       NaN
# 40023  2016      9   NaN   NaN  ...      NaN       NaN       NaN       NaN
# 40024  2016      7   NaN   NaN  ...      NaN       NaN       NaN       NaN
# 40025  2016      8   NaN   NaN  ...      NaN       NaN       NaN       NaN
#
# [216261 rows x 108 columns]

# %%
df_delitos_2 = df_delitos.drop(df_delitos.columns[[0]], axis = 'columns')

df_delitos_2.head(3)
# Out:
#       ID_VIV           ID_HOG              ID_PER  ... BP1_25_2  BP1_26_1  BP1_26_2
# 0  101520.03  0101520.03.01\r  0101520.03.01.03\r  ...      NaN       NaN       NaN
# 1  160019.04  0160019.04.01\r  0160019.04.01.01\r  ...      NaN       NaN       NaN
# 2  102339.17  0102339.17.01\r  0102339.17.01.03\r  ...      NaN       NaN       NaN
#
# [3 rows x 145 columns]
